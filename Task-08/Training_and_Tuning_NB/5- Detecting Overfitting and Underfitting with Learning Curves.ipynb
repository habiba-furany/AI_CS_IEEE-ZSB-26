# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# %reload_ext autoreload

import pandas as pd
import numpy as np

from utils import randomize, draw_learning_curves
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
# Import data from csv file
data = pd.read_csv('data.csv')

# %%
# Fix random seed
np.random.seed(55)

# Prepare features and label data
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %% [markdown]
# ### Uncomment the code for each one, and examine the learning curve that gets drawn.

# %%
# TODO: Uncomment one of the three classifiers, and hit "Test Run"
# to see the learning curve. Use these to answer the quiz below.

### Logistic Regression
estimator_log = LogisticRegression()

## Decision Tree
estimator_gboost = GradientBoostingClassifier()

## Support Vector Machine
estimator_svx = SVC(kernel='rbf', gamma=1000)

# %%
draw_learning_curves(X, y, estimator_log, 10)

# %%
draw_learning_curves(X, y, estimator_gboost, 10)
# Out:
# c:\Users\habib\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 1 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\habib\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\habib\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
draw_learning_curves(X, y, estimator_svx, 10)

# %% [markdown]
# Quiz Question
#
# From the models above, which model underfits, which one overfits, and which one is just right?
#
# Logistic Regression
#
# Decision Tree
#
# Support Vector Machine

# %% [markdown]
# Enter Answers Here:

# %% [markdown]
# logistic overfits

# %% [markdown]
# .svm underfits

# %% [markdown]
# . dicition tree fits well
